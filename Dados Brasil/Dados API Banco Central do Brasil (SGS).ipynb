# %% [markdown]
# #  Dados API Banco Central do Brasil (SGS)

# %% [markdown]
# ### Importando Bibliotecas

# %% [markdown]
# ##### Meu post explicativo no steemit: https://bit.ly/3cBjQv9

# %%
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

import matplotlib
matplotlib.rcParams['figure.figsize'] = (16,8)

# %% [markdown]
# #### Obtendo Dados através da API do Banco Central do Brasil

# %%
def consulta_bc(codigo_bcb):
  url = 'http://api.bcb.gov.br/dados/serie/bcdata.sgs.{}/dados?formato=json'.format(codigo_bcb)
  df = pd.read_json(url)
  df['data'] = pd.to_datetime(df['data'], dayfirst=True)
  df.set_index('data', inplace=True)
  return df

# %% [markdown]
# #### Exemplo de Consulta à API

# %%
#Dados taxa de Desemprego pnad
pnad = consulta_bc(24369)
pnad
# Out:
#             valor
# data
# 2012-03-01    7.9
# 2012-04-01    7.7
# 2012-05-01    7.6
# 2012-06-01    7.5
# 2012-07-01    7.4
# ...           ...
# 2020-05-01   12.9
# 2020-06-01   13.3
# 2020-07-01   13.8
# 2020-08-01   14.4
# 2020-09-01   14.6
#
# [103 rows x 1 columns]

# %%
pnad.plot()
# Out:
# <AxesSubplot:xlabel='data'>

# %%
#Reservas internacionais(dólares)
reservas_internacionais = consulta_bc(13621)
reservas_internacionais.plot()
# Out:
# <AxesSubplot:xlabel='data'>

# %%
#Ìndice de inflação IPCA
ipca = consulta_bc(433)
ipca.plot()
# Out:
# <AxesSubplot:xlabel='data'>

# %%
# Ìndice de inflação IGPM
igpm = consulta_bc(189)
igpm.plot()
# Out:
# <AxesSubplot:xlabel='data'>

# %%
#Taxa selic meta
selic_meta = consulta_bc(432)
selic_meta.plot()
# Out:
# <AxesSubplot:xlabel='data'>

# %%
#Agregados monetário 
agregado = consulta_bc(27785)
agregado.plot()
#-27783-	Papel moeda em poder do público (saldo diário) 
#-27784	Depósitos à vista (saldo diário) 
#-27785	M1 (saldo diário)
#-27786	Papel moeda em poder do público (média nos dias úteis do mês) - Novo
#-27787	Depósitos à vista (média nos dias úteis do mês) - Novo
#-27788	M1 (média dos dias úteis do mês) - Novo
#-27789	Papel moeda em poder do público (saldo em final de período) - Novo
#-27790	Depósitos à vista (saldo em final de período) - Novo
#-27791	M1 (saldo em final de período) - Novo
#-27841	M1 (saldo em final de período) - Novo - sazonalmente ajustado
# Out:
# <AxesSubplot:xlabel='data'>
